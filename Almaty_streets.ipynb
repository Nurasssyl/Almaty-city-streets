# %% [markdown]
# <a href="https://colab.research.google.com/github/Nurasssyl/Almaty-city-streets/blob/main/Almaty_streets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install osmnx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.2/107.2 kB 1.2 MB/s eta 0:00:00
# ...

# %%
import osmnx as ox

# %%
admin = ox.geocode_to_gdf('Oskemen')
admin_poly = admin.geometry.values[0]
admin_poly
# Out:
# <POLYGON ((82.396 49.92, 82.458 49.915, 82.428 49.881, 82.466 49.872, 82.495...>

# %%
G = ox.graph_from_polygon(admin_poly)

# %%
G.number_of_nodes(), G.number_of_edges
# Out:
# (16692,
#  <bound method MultiGraph.number_of_edges of <networkx.classes.multidigraph.MultiDiGraph object at 0x7cccaa0b5240>>)

# %%
nodes, edges = ox.graph_to_gdfs(G)

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
f, ax = plt.subplots(1, figsize=(10, 10))
edges.plot(ax=ax, edgecolor = 'orange', linewidth = 0.3)
ax.set_title("Oskemen", fontsize=20, color='white', fontname='Arial')
ax.axis('off')
# Out:
# (82.391754415, 82.995871885, 49.744240940000005, 50.05354686)
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.

# %%
# Сохранение визуализации
output_path = 'Oskemen_street_network.png'
f.savefig(output_path, dpi=300, bbox_inches='tight', facecolor=f.get_facecolor())

from google.colab import files
files.download(output_path)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
